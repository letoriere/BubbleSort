# %%
def bubblesort(list1):
    for index in range(len(list1)-1,0,-1):
         for i in range(index):
            if list1[i]>list1[i+1]:
                temp = list1[i]
                list1[i] = list1[i+1]
                list1[i+1] = temp

# %%
def verify(list1):
    for index in range(len(list1)-1,0,-1):
        for i in range(index):
            if list1[i]>list1[i+1]:
                global verification
                verification = verification + 1
    if verification == 0:
        print('List is sorted.\n')
    else:
        print('List has not been sorted.\n')

# %%
def test(bubblesort):
    start_time = time.time()
    bubblesort(list1)
    print('The sorting took %s seconds.' % (time.time() - start_time))

# %%
import random
import time

n = (int)(input('N = '))
print('')

list1 = random.sample(range(-100000, 100000), n)
print('Unsorted list:')
print(list1)
print('')
# Out:
# N = 100
#
# Unsorted list:
# [-4875, 43769, -93285, -46187, 98139, -83199, 75526, 15230, -8023, -24964, -88043, -82141, 89388, 89986, -8368, 45090, -99500, 64424, 12629, 45212, 10548, 25993, -55447, -59128, 46764, -85689, -2780, 46888, 97122, -35358, 3805, -78106, -65994, -25465, 55312, 60029, 78079, 94142, 22037, 82854, -5326, 78351, -61643, 6989, -48840, 19698, -57804, -13523, 75678, 84372, 1088, 20005, -7843, -63832, -77360, 52363, 74078, 47218, 75908, -8884, -41337, 14568, -95017, -34714, 12224, 93751, -95398, 108, -13567, 13587, -93637, 69763, -69694, 33559, 61524, -74417, -91126, 75296, -61491, 96318, 42138, -85328, 43616, -12482, -94020, -99089, -40434, -29477, -5902, 93458, 65687, -26541, -27679, 59698, -52012, -47029, 80955, 712, -34454, -48709]

# %%
bubblesort(list1)
print('Sorted list:')
print(list1)
print('')
# Out:
# Sorted list:
# [-99500, -99089, -95398, -95017, -94020, -93637, -93285, -91126, -88043, -85689, -85328, -83199, -82141, -78106, -77360, -74417, -69694, -65994, -63832, -61643, -61491, -59128, -57804, -55447, -52012, -48840, -48709, -47029, -46187, -41337, -40434, -35358, -34714, -34454, -29477, -27679, -26541, -25465, -24964, -13567, -13523, -12482, -8884, -8368, -8023, -7843, -5902, -5326, -4875, -2780, 108, 712, 1088, 3805, 6989, 10548, 12224, 12629, 13587, 14568, 15230, 19698, 20005, 22037, 25993, 33559, 42138, 43616, 43769, 45090, 45212, 46764, 46888, 47218, 52363, 55312, 59698, 60029, 61524, 64424, 65687, 69763, 74078, 75296, 75526, 75678, 75908, 78079, 78351, 80955, 82854, 84372, 89388, 89986, 93458, 93751, 94142, 96318, 97122, 98139]

# %%
verification = 0
verify(list1)
# Out:
# List is sorted.

# %%
test(bubblesort)
# Out:
# The sorting took 0.0009818077087402344 seconds.

# %%
# %matplotlib notebook
from matplotlib.pyplot import *
from numpy import *

x = array([10,100,1000,10000,20000,30000,40000,50000,60000,70000,80000,90000,100000])
y = array([0.0,0.0009965896606445312,0.11072468757629395,10.840298414230347,39.55334162712097,95.97635316848755,182.85597443580627,284.6944351196289,412.46542096138,524.6578049659729,733.012255191803,910.6607294082642,1185.147402048111])

p2 = poly1d(polyfit(x,y,2))
xp = linspace(0,100000,100)

plot(x,y,'o')
plot(xp,polyval(p2,xp),'r-')

xlabel('Amount of Numbers') 
ylabel('Time (s)')  
title('Time vs N')

show()
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
print(p2)
# Out:
#            2
# 1.226e-07 x - 0.0006963 x + 3.31
