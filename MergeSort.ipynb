# %%
def mergesort(list1):
    if len(list1)>1:
        mid = len(list1)//2
        lefthalf = list1[:mid]
        righthalf = list1[mid:]

        mergesort(lefthalf)
        mergesort(righthalf)
        merge(list1, lefthalf, righthalf)

# %%
def merge(list1, lefthalf, righthalf):
        i=0
        j=0
        k=0
        
        while i < len(lefthalf) and j < len(righthalf):
            if lefthalf[i] < righthalf[j]:
                list1[k]=lefthalf[i]
                i=i+1
            else:
                list1[k]=righthalf[j]
                j=j+1
            k=k+1

        while i < len(lefthalf):
            list1[k]=lefthalf[i]
            i=i+1
            k=k+1

        while j < len(righthalf):
            list1[k]=righthalf[j]
            j=j+1
            k=k+1

# %%
def verify(list1):
    for i in range(0,len(list1)-1,+1):
        if list1[i]>list1[i+1]:
            global verification
            verification = verification + 1
    if verification == 0:
        print('List is sorted.\n')
    else:
        print('List has not been sorted.\n')

# %%
def test():
    start_time = time.time()
    mergesort(list1)
    print('The sorting took %s seconds.' % (time.time() - start_time))

# %%
import random
import time

n = (int)(input('N = '))
print('')

list1 = random.sample(range(-100000, 100000), n)
print('Unsorted list:')
print(list1)
print('')
# Out:
# N = 100
#
# Unsorted list:
# [60162, 67733, 21279, 91263, -54455, -1738, 24209, -95656, -77254, 22922, -26193, 85483, 49738, 34293, -65088, 41687, 27934, -2016, 91637, -14738, 7702, -71196, 70289, 67430, 98064, 94843, -66935, 55050, -88552, 70614, -58814, -94537, -51971, -27270, 20030, 38789, -69317, 89786, 85107, 10356, -40581, -9254, -87777, -71853, -77705, 10622, 19660, -64897, 13796, 61765, -84247, -78120, 78084, -55447, 12013, 21969, 7832, 97908, -60621, 22653, -64044, 56118, 4415, 81401, 52761, 28192, 86454, 11027, 77909, 46570, 33599, 21133, -58941, -54179, -17219, -61519, 63285, 41606, 28771, 86036, 60864, 15793, 85634, -26009, -30621, -41153, -18560, 92800, -58817, -9130, -26370, 85120, 64304, 27049, -95384, -27787, -41396, 94474, -19800, -32743]

# %%
mergesort(list1)
print('Sorted list:')
print(list1)
print('')
# Out:
# Sorted list:
# [-95656, -95384, -94537, -88552, -87777, -84247, -78120, -77705, -77254, -71853, -71196, -69317, -66935, -65088, -64897, -64044, -61519, -60621, -58941, -58817, -58814, -55447, -54455, -54179, -51971, -41396, -41153, -40581, -32743, -30621, -27787, -27270, -26370, -26193, -26009, -19800, -18560, -17219, -14738, -9254, -9130, -2016, -1738, 4415, 7702, 7832, 10356, 10622, 11027, 12013, 13796, 15793, 19660, 20030, 21133, 21279, 21969, 22653, 22922, 24209, 27049, 27934, 28192, 28771, 33599, 34293, 38789, 41606, 41687, 46570, 49738, 52761, 55050, 56118, 60162, 60864, 61765, 63285, 64304, 67430, 67733, 70289, 70614, 77909, 78084, 81401, 85107, 85120, 85483, 85634, 86036, 86454, 89786, 91263, 91637, 92800, 94474, 94843, 97908, 98064]

# %%
verification = 0
verify(list1)
# Out:
# List is sorted.

# %%
list1 = random.sample(range(-100000, 100000), n)

test()
# Out:
# The sorting took 0.001008749008178711 seconds.

# %%
# %matplotlib notebook
from matplotlib.pyplot import *
from numpy import *

x = array([10,100,1000,10000,20000,30000,40000,50000,60000,70000,80000,90000,100000])
y = array([0.000076460838317871,0.00062466144561768,0.0070228934288025,0.10114334583282,0.2193506026268,0.34851048231125,0.48330543279648,0.60795005559921,0.75466223239899,0.8919153046608,1.0230011296272,1.1891118764877,1.3097086572647])

p1 = poly1d(polyfit(x,y,1))
xp = linspace(0,100000,100)

plot(x,y,'o')
plot(xp,polyval(p1,xp),'r-')

xlabel('Amount of Numbers') 
ylabel('Time (s)')  
title('Time vs N')

show()
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %%
print(p1)
# Out:
#
# 1.315e-05 x - 0.02395
