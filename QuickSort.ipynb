# %%
def partition(list1,low,high):
    i = ( low-1 )
    pivot = list1[high]
 
    for j in range(low , high):
        if   list1[j] <= pivot:
            i = i+1
            list1[i],list1[j] = list1[j],list1[i]

    list1[i+1],list1[high] = list1[high],list1[i+1]
    return ( i+1 )

# %%
def quicksort(list1,low,high):
    if low < high:

        pi = partition(list1,low,high)

        quicksort(list1, low, pi-1)
        quicksort(list1, pi+1, high)

# %%
def verify(list1):
    for i in range(0,len(list1)-1,+1):
        if list1[i]>list1[i+1]:
            global verification
            verification = verification + 1
    if verification == 0:
        print('List is sorted.\n')
    else:
        print('List has not been sorted.\n')

# %%
def test():
    start_time = time.time()
    quicksort(list1,0,n-1)
    print('The sorting took %s seconds.' % (time.time() - start_time))

# %%
import random
import time

n = (int)(input('N = '))
print('')

list1 = random.sample(range(-100000, 100000), n)
print('Unsorted list:')
print(list1)
print('')
# Out:
# N = 100
#
# Unsorted list:
# [96422, -68045, 4287, -22905, 33850, -95974, 30901, -23285, -81757, 71143, -10428, -10957, 87850, -52550, 8596, 7317, -20123, 94091, -81987, 34066, -97032, -23629, -51504, -74340, -53019, -62976, 9567, -46133, 17135, -21356, -45181, -37464, -73541, 76567, -26478, -4772, -14500, 93718, 77025, 35393, -4387, 77119, 89179, -41781, 7906, 73149, 70962, 68898, 90933, 10158, 35155, 66171, 70811, 17687, 81763, -16516, -54367, 75338, -74981, -57924, 43099, -96656, 23909, -25206, 73052, -34486, -68822, 98130, 26305, 70380, -96807, 9713, 3181, -8509, 13837, 23917, -65688, -5189, 4461, 22718, 30151, 147, -32602, 82172, 78970, 61529, 26519, -52949, -82053, -5335, -7630, -3458, -97152, -32174, -65886, 15286, -94018, 74061, -79438, -44848]

# %%
quicksort(list1,0,n-1)
print('Sorted list:')
print(list1)
print('')
# Out:
# Sorted list:
# [-97152, -97032, -96807, -96656, -95974, -94018, -82053, -81987, -81757, -79438, -74981, -74340, -73541, -68822, -68045, -65886, -65688, -62976, -57924, -54367, -53019, -52949, -52550, -51504, -46133, -45181, -44848, -41781, -37464, -34486, -32602, -32174, -26478, -25206, -23629, -23285, -22905, -21356, -20123, -16516, -14500, -10957, -10428, -8509, -7630, -5335, -5189, -4772, -4387, -3458, 147, 3181, 4287, 4461, 7317, 7906, 8596, 9567, 9713, 10158, 13837, 15286, 17135, 17687, 22718, 23909, 23917, 26305, 26519, 30151, 30901, 33850, 34066, 35155, 35393, 43099, 61529, 66171, 68898, 70380, 70811, 70962, 71143, 73052, 73149, 74061, 75338, 76567, 77025, 77119, 78970, 81763, 82172, 87850, 89179, 90933, 93718, 94091, 96422, 98130]

# %%
verification = 0
verify(list1)
# Out:
# List is sorted.

# %%
list1 = random.sample(range(-100000, 100000), n)

test()
# Out:
# The sorting took 0.0009951591491699219 seconds.

# %%
# %matplotlib notebook 
from matplotlib.pyplot import * 
from numpy import *

x = array([10,100,1000,10000,20000,30000,40000,50000,60000,70000,80000,90000,100000]) 
y = array([0.000025293827056885,0.00013230323791504,0.0050248408317566,0.053018434047699,0.11295862674713,0.17492687702179,0.24215344667435,0.30709529161453,0.37735997676849,0.44252943277359,0.51045165777206,0.58129719495773,0.64480177402496])

p1 = poly1d(polyfit(x,y,1)) 
xp = linspace(0,100000,100)

plot(x,y,'ro') 
plot(xp,polyval(p1,xp),'g-')

xlabel('Amount of Numbers') 
ylabel('Time (s)') 
title('Time vs N')

show()
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %%
print(p1)
# Out:
#
# 6.474e-06 x - 0.008936
